# %%
import pandas as pd

# %%
cities_pd = pd.read_csv('Resources/city_weather.csv')

# %%
cities_pd.head()
# Out:
#    Unnamed: 0          City  Latitude  Longitude  Max Temperature  Humidity  \
# 0           0         sitka     57.05    -135.33            53.60        81
# 1           1        faanui    -16.48    -151.75            77.27        81
# 2           2   thohoyandou    -22.95      30.48            81.90        19
# 3           3       bubaque     11.28     -15.83            78.80        86
# 4           4  puerto ayora     -0.74     -90.35            73.40        69
#
#    Cloudiness  Wind Speed Country        Date
# 0          75        3.20      US  1598722385
# 1          37       26.22      PF  1598722054
# 2          15        3.62      ZA  1598722562
# 3         100       18.79      GW  1598722383
# 4          20       19.46      EC  1598722347

# %%
cities_pd = cities_pd.rename(columns={"Unnamed: 0": "City ID"})
cities_pd
# Out:
#      City ID          City  Latitude  Longitude  Max Temperature  Humidity  \
# 0          0         sitka     57.05    -135.33            53.60        81
# 1          1        faanui    -16.48    -151.75            77.27        81
# 2          2   thohoyandou    -22.95      30.48            81.90        19
# 3          3       bubaque     11.28     -15.83            78.80        86
# 4          4  puerto ayora     -0.74     -90.35            73.40        69
# ..       ...           ...       ...        ...              ...       ...
# 540      540       zhangye     38.93     100.45            56.64        70
# 541      541         sabla     12.75       4.71            80.40        74
# 542      542  duiwelskloof    -23.69      30.14            79.93        20
# 543      543          mitu      1.20     -70.17            76.77        95
# 544      544    manapparai     10.60      78.42            86.00        74
#
#      Cloudiness  Wind Speed Country        Date
# ...

# %%
cities_pd = cities_pd.set_index("City ID")
# cities_pd.reset_index(inplace=True)

# %%
# Assistance in using to_html: geeksforgeeks.org/python-pandas-dataframe-to_html-method/
print(cities_pd.to_html())

# %%
cities_pd.reset_index(inplace=True)

# %%
cities_pd.
# Out:
#      City ID          City  Latitude  Longitude  Max Temperature  Humidity  \
# 0          0         sitka     57.05    -135.33            53.60        81
# 1          1        faanui    -16.48    -151.75            77.27        81
# 2          2   thohoyandou    -22.95      30.48            81.90        19
# 3          3       bubaque     11.28     -15.83            78.80        86
# 4          4  puerto ayora     -0.74     -90.35            73.40        69
# ..       ...           ...       ...        ...              ...       ...
# 540      540       zhangye     38.93     100.45            56.64        70
# 541      541         sabla     12.75       4.71            80.40        74
# 542      542  duiwelskloof    -23.69      30.14            79.93        20
# 543      543          mitu      1.20     -70.17            76.77        95
# 544      544    manapparai     10.60      78.42            86.00        74
#
#      Cloudiness  Wind Speed Country        Date
# ...
